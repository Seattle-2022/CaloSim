# %% [markdown]
# # Example to load and evaluate fast calorimeter simulation dataset

# %% [markdown]
# By Q.LIU.(qibin.liu@cern.ch) Based on [official repo](https://calochallenge.github.io)

# %% [markdown]
# # Background
# Calorimeter is one of the important detector in high energy physics experiment. As the name noted, this kind of instrument is used to measure the energy of particle, by monitoring the heat, flash light, discharge or other output between energitic particle and calorimeter active material.
#
# This kind of detector is also widely used in medical science, e.g. the main and largest part of CT and PET is some kind of calorimeter in order to measure the x-ray or other particle and to identify medical observation.
#
# The calorimeter of collider experiment looks like (from CERN)
#
# ![](https://mediaarchive.cern.ch/MediaArchive/Photo/Public/2008/0803015/0803015_01/0803015_01-A5-at-72-dpi.jpg)
#
# And the one used in PET (from wiki)
#
# ![](https://upload.wikimedia.org/wikipedia/commons/f/fc/PET-detectorsystem_2.png)
#
# The calorimeter data should be compared with simulation in order to study the real physics and identified the underlaying process. In that sense almost all the collider study need to generate or simulate the particle interaction with calorimeter, not only in the R&D of this detector but also in the period of data taking and data analysis.
#
# Triditional way to simulate this process involves the "showering", one particle could split into thousands of thousands secondary particles when they fly in the calorimeter and hit material. The compution is huge since it is "Markov Chain Monte Carlo" process and could not be well paralleled. like the plot (from Sven Menke@MPP)
#
# ![](https://www.mppmu.mpg.de/~menke/elss/gifs/fe24elwhite_small.gif)
#
# Fast calo sim project aim to design generative machine learning method to directly sampled the output of calorimeter, based on the incident particle, and bypass the hugh computing effort. It could save more than millions of core-hours and euros if finally applied, e.g. in ATLAS experiment.
#
# ![image.png](attachment:e3d21c0f-58a2-4347-bdbe-c8ed842302c0.png)

# %% [markdown]
# # Prepare Dataset

# %% [markdown]
# The datasets could be found in [official](https://calochallenge.github.io/homepage/) websites. Here we focus on the dataset-2 which is the medium complexity and representive enough.

# %%
# %cd ..
# %pwd
dataset_train = 'CaloChallenge/Datasets/dataset_2_1.hdf5'
dataset_eval = 'CaloChallenge/Datasets/dataset_2_2.hdf5'
# Out:
# C:\Users\tangd\zz-Internship

# %% [markdown]
# # Inspect the dataset and Understand the structure

# %%
import h5py as h5
from matplotlib import pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm
import matplotlib as mpl

# %%
# load data
f=h5.File(dataset_train)
print(f['incident_energies'].shape) # condition
print(f['showers'].shape) # data to begenerated
f.keys()
for k in f.keys():
    print(f"{k}:{f[k].dtype}, {f[k].shape}")
f2=h5.File(dataset_eval)
for k in f2.keys():
    print(f"{k}:{f2[k].dtype}, {f2[k].shape}")
# Out:
# (100000, 1)
# (100000, 6480)
# incident_energies:float64, (100000, 1)
# showers:float64, (100000, 6480)
# incident_energies:float64, (100000, 1)
# showers:float64, (100000, 6480)

# %%
# change the shape to be more interpretable
data=np.reshape(f['showers'][:1000],(-1,45,16,9))
# the shape should be [1000,45,16,9]
print(f"data.shape: {data.shape}")
# resulted in 3D cylinder structure: 45 layers in depth(Z); 16 segmentation in angular direction (alpha) and 9 segmentation in radical direction (R)
cond=f['incident_energies'][:1000]
# Out:
# data.shape: (1000, 45, 16, 9)

# %%
# investigate the condition
# All the value in the unit of "MeV" and we will hide it
plt.hist(cond,bins=100,log=True)
print(f"max cond={max(f['incident_energies'])}")
plt.xlabel("Condition")
plt.ylabel("NSample")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 4
#       1 # investigate the condition
#       2 # All the value in the unit of "MeV" and we will hide it
#       3 plt.hist(cond,bins=100,log=True)
# ----> 4 print(f"max cond={f['incident_energies'].max()}")
#       5 plt.xlabel("Condition")
#       6 plt.ylabel("NSample")
#
# AttributeError: 'Dataset' object has no attribute 'max'

# %%
# investgate the data range
fig,axs=plt.subplots(4,figsize=(5,14))
axs[0].hist(data.flatten(),bins=100,log=True)
axs[0].set_xlabel("Voxel energy")
axs[0].set_ylabel("NVoxel in all sample")
# largest value coul up to 6000, long tail
axs[1].hist(np.log10(1+data.flatten()),bins=100,log=True)
axs[1].set_xlabel("log10(Voxel energy)")
axs[1].set_ylabel("NVoxel in all sample")
# while very sharp peak around 0
axs[2].hist(data.flatten(),range=[0,1],bins=100,log=True)
axs[2].set_xlabel("Voxel energy")
axs[2].set_ylabel("NVoxel in all sample")
axs[3].hist(data.flatten(),range=[0,0.1],bins=100,log=True)
axs[3].set_xlabel("Voxel energy")
axs[3].set_ylabel("NVoxel in all sample")
# Out:
# Text(0, 0.5, 'NVoxel in all sample')

# %%
# One important feature, the sum(voxel) if highly correlated to the condition
plt.hist2d(np.sum(data,axis=(-1,-2,-3)),cond[:,0],bins=100,norm=LogNorm());
plt.xlabel("Sum(voxel)")
plt.ylabel("Cond")
# Out:
# Text(0, 0.5, 'Cond')

# %%
# one shower could looks like
def bettert_cmap():
    # misc staff to make colormap better
    from matplotlib.colors import ListedColormap
    # Choose colormap which will be mixed with the alpha values
    cmap = plt.cm.afmhot_r

    # Get the colormap colors
    my_cmap = cmap(np.arange(cmap.N))
    # Define the alphas in the range from 0 to 1
    alphas = np.linspace(0, 1, cmap.N)
    # Define the background as white
    BG = np.asarray([1., 1., 1.,])
    # Mix the colors with the background
    for i in range(cmap.N):
        my_cmap[i,:-1] = my_cmap[i,:-1] * alphas[i] + BG * (1.-alphas[i])
    # Create new colormap which mimics the alpha values
    my_cmap = ListedColormap(my_cmap)
    cmap = plt.cm.plasma
    cmap = cmap(np.arange(cmap.N))
    cmap[:, 3] = np.linspace(0.05, 1, 256)
    cmap = ListedColormap(cmap)
    return cmap
def plot_shower(x,ievt=123):
    rad = np.linspace(0, 1, 9)
    ang = np.linspace(0, 2*np.pi, 16)
    r, th = np.meshgrid(rad, ang)

    ncol = 9
    sz = 1.5
    for j in range(5):
        plt.figure(figsize=sz*plt.figaspect(1/ncol))
        for i in range(ncol):
            il = i+j*ncol
            if il >= x.shape[1]: break
            ax = plt.subplot(1, ncol, i+1, projection='polar')
            ax.pcolormesh(th, r, x[ievt,il], shading='auto', cmap=bettert_cmap())
            ax.axis('off');
            ax.text(4*np.pi/5, 1.2, str(il))
plot_shower(data)

# %%
# One example "physical" variable: energy sum in layer 3rd
Esum3=np.sum(data[:,2,:,:],axis=(-1,-2))
plt.hist(Esum3,bins=100,log=True)
plt.xlabel("E Layer 3rd")
plt.ylabel("NSample")
# we want the generated datat reproduce these physical variable distribution
# Out:
# Text(0, 0.5, 'NSample')

# %% [markdown]
# # Evaluate the quality of "fast simulation"

# %% [markdown]
# modified based on [official tool](https://github.com/CaloChallenge/homepage)

# %% [markdown]
# ## Physics Metric

# %% [markdown]
# We evaluete the dataset by using `seperation`, which is the difference between two histograms:
#
#  - one histogram made using truth data
#  - the other with generated data
#
# The histogramed variable is usually interesting in physics and the closer two histograms are, the better generated in physics

# %% [markdown]
# The detais of the physics variables are listed as below (in total 227 variables, so that 227 metrics)
#
# ![image.png](attachment:c1bb9ef4-7813-415f-8531-e9cfb3a95f21.png)

# %%
# %pwd
# Out:
# 'C:\\Users\\tangd\\zz-Internship\\CaloChallenge\\code'

# %%
# %cd CaloChallenge/code/
# %run evaluate.py \
            --input_file ../Datasets/dataset_2_1.hdf5\
            --reference_file ../Datasets/dataset_2_2.hdf5\
            --mode hist-p \
            --dataset 2 \
            --output_dir eval_metrics_001
# Out:
# Checking if input file has the correct form ...
# Found 100000 events in the file.
# Checking if input file has the correct form: DONE
#
# Extracting showers from input file ...
# Extracting energy from input file: DONE.
#
# Storing reference .pkl file in folder: ../Datasets
# Checking if reference file has the correct form ...
# Found 100000 events in the file.
# Checking if reference file has the correct form: DONE
#
# Extracting showers from reference file ...
# Extracting energy from reference file: DONE.
#
# Loading .pkl reference
# Loading file with high-level features.
# Calculating high-level features for histograms ...
# Calculating high-level features for histograms: DONE.
#
# Plotting histograms ...
# voxel range 6004.412635610716 0.0
# [0.13834315 0.1350209  0.13208622 0.12739184 0.12288703 0.11652315
#  0.10974573 0.10256474 0.09557271 0.08880705]
# C:\Users\tangd\zz-Internship\CaloChallenge\code\evaluate_plotting_helper.py:589: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Plotting histograms: DONE.

# %%
# read out the seperation value and plot
import pandas as pd
def load_metrics(fn):
    ret={}
    with open(fn) as f:
        m=None
        for l in f:
            l=l.strip()
            if l=="" or "List" in l:
                continue
            l=l.replace(":","")
            if m is None:
                s=l.split(" ")[-1]
                if s.isnumeric():
                    i=int(s)
                    t=" ".join(l.split(" ")[:-1])
                    m=(t,i)
                    if t in ret:
                        ret[t][i]=-1
                    else:
                        ret[t]={i:-1}
                else:
                    i=-1
                    t=l
                    m=(t,i)
                    if t in ret:
                        ret[t][i]=-1
                    else:
                        ret[t]={i:-1}
            else:
                ret[m[0]][m[1]]=float(l)
                m=None
    return pd.DataFrame.from_dict(ret)

# enlarge a little bit the title in plot
plt.rc('text', usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{amsmath,amssymb}')
plt.rc('font', family='serif')
params = {
         # 'legend.fontsize': 'x-large',
         # 'figure.figsize': (15, 5),
         'axes.labelsize': 'xx-large',
         'axes.titlesize': 20,
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'
}
plt.rcParams.update(params)

def plot_metrics(fn):
    d=load_metrics(fn)
    fig,ax=plt.subplots(1,figsize=(8.5,5.5))
    d[["E layer","EC Eta layer","EC Phi layer","Width Eta layer","Width Phi layer"]].plot(
        logy=True,ax=ax,linestyle='none',markersize=8)
    markers=[
        "*","P","+","p","d",
    ]
    for i, line in enumerate(ax.get_lines()):
        line.set_marker(markers[i])
    ax.set_xlabel("Layer")
    ax.set_ylabel("Sep. Metric")
    ax.set_ylim(1E-4,0.2)
    ax.set_title(f"Performance")
    ax.legend(frameon=False,fontsize = 13)
    plt.show()

# %% [markdown]
# ### Metrics of each layer (5 metric/layer, 45 layer in total 225 values)
# $E(K)$, $\overline{\eta (K)}$, $\overline{\phi (K)}$, $\sigma_{\eta (K)}$, $\sigma_{\phi (K)}$

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
plot_metrics("eval_metrics_001/histogram_chi2_2.txt")

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Total energy metric and voxel energy metric (2 metrics)
# $E_{tot}/E_{cond}$, $E_i$

# %% [markdown]
# #### Can't do this because all of them are pdfs I will fix this

# %% [markdown]
# To be simple, you can take $max(metrics)$ to get the comined metric, which indicates the worst performance of all evaluated physics metric.
#
# The model could reach seperation for all different variables as low as `1E-4` is seens as good

# %% [markdown]
# ## Classifier Metric

# %% [markdown]
# The other metric is called `classifier metric`, which is we train another simplest model to seperate the truth v.s. generated
#
# The lower AUC is, after 50 epoches, the better/higher fidelity the generation is

# %%
# %pwd

# %%
# %run evaluate.py \
            --input_file ../Datasets/dataset_2_1.hdf5\
            --reference_file ../Datasets/dataset_2_2.hdf5\
            --mode cls-low \
            --dataset 2 \
            --output_dir eval_metrics_002 \
            --save_mem
# Out:
# Checking if input file has the correct form ...
# Found 100000 events in the file.
# Checking if input file has the correct form: DONE
#
# Extracting showers from input file ...
# Extracting showers from input file: DONE.
#
# Storing reference .pkl file in folder: ../Datasets
# Checking if reference file has the correct form ...
# Found 100000 events in the file.
# Checking if reference file has the correct form: DONE
#
# Extracting showers from reference file ...
# Extracting showers from reference file: DONE.
#
# Loading .pkl reference
# Loading file with high-level features.
# Calculating high-level features for classifier ...
# Calculating high-level features for classifer: DONE.
#
# Extracting showers from 0.0 file ...
# Extracting showers from 0.0 file: DONE.
#
# Extracting showers from 1.0 file ...
# Extracting showers from 1.0 file: DONE.
#
# Using cuda:0
# DNN(
#   (inputlayer): Linear(in_features=6481, out_features=512, bias=True)
#   (outputlayer): Linear(in_features=512, out_features=1, bias=True)
#   (layers): Sequential(
#     (0): Linear(in_features=6481, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=512, out_features=512, bias=True)
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Dropout(p=0.0, inplace=False)
#     (9): Linear(in_features=512, out_features=1, bias=True)
#   )
# )
# cls-low has 3844609 parameters
# Epoch   1 / 50, step    0 / 120; loss 0.6926
# Epoch   1 / 50, step   60 / 120; loss 0.6931
# Accuracy on training set is 0.4993
# Accuracy on test set is 0.5
# AUC on test set is 0.5033748362499999
# BCE loss of test set is 0.6931, JSD of the two dists is 0.0000
# Epoch   2 / 50, step    0 / 120; loss 0.6931
# Epoch   2 / 50, step   60 / 120; loss 0.6932
# Accuracy on training set is 0.498375
# Accuracy on test set is 0.5015
# AUC on test set is 0.50334187125
# BCE loss of test set is 0.6931, JSD of the two dists is 0.0000
# Epoch   3 / 50, step    0 / 120; loss 0.6931
# Epoch   3 / 50, step   60 / 120; loss 0.6933
# Accuracy on training set is 0.4992916666666667
# Accuracy on test set is 0.5
# AUC on test set is 0.5032939325000001
# BCE loss of test set is 0.6931, JSD of the two dists is -0.0000
# Epoch   4 / 50, step    0 / 120; loss 0.6931
# Epoch   4 / 50, step   60 / 120; loss 0.6935
# Accuracy on training set is 0.5008416666666666
# Accuracy on test set is 0.50025
# AUC on test set is 0.5032900037500001
# BCE loss of test set is 0.6932, JSD of the two dists is -0.0000
# Epoch   5 / 50, step    0 / 120; loss 0.6931
# Epoch   5 / 50, step   60 / 120; loss 0.6929
# Accuracy on training set is 0.505575
# Accuracy on test set is 0.502325
# AUC on test set is 0.50328287
# BCE loss of test set is 0.6931, JSD of the two dists is -0.0000
# Epoch   6 / 50, step    0 / 120; loss 0.6932
# Epoch   6 / 50, step   60 / 120; loss 0.6928
# Accuracy on training set is 0.5045333333333333
# Accuracy on test set is 0.5001
# AUC on test set is 0.49679019750000003
# BCE loss of test set is 0.6932, JSD of the two dists is -0.0001
# Epoch   7 / 50, step    0 / 120; loss 0.6934
# Epoch   7 / 50, step   60 / 120; loss 0.6931
# Accuracy on training set is 0.5061333333333333
# Accuracy on test set is 0.5008
# AUC on test set is 0.50360728125
# BCE loss of test set is 0.6944, JSD of the two dists is -0.0018
# Epoch   8 / 50, step    0 / 120; loss 0.6888
# Epoch   8 / 50, step   60 / 120; loss 0.6899
# Accuracy on training set is 0.5194166666666666
# Accuracy on test set is 0.500125
# AUC on test set is 0.5003015125
# BCE loss of test set is 0.6978, JSD of the two dists is -0.0067
# Epoch   9 / 50, step    0 / 120; loss 0.6868
# Epoch   9 / 50, step   60 / 120; loss 0.6870
# Accuracy on training set is 0.5255333333333333
# Accuracy on test set is 0.497875
# AUC on test set is 0.49739146375
# BCE loss of test set is 0.6968, JSD of the two dists is -0.0053
# Epoch  10 / 50, step    0 / 120; loss 0.6847
# Epoch  10 / 50, step   60 / 120; loss 0.6851
# Accuracy on training set is 0.530125
# Accuracy on test set is 0.50145
# AUC on test set is 0.500458865
# BCE loss of test set is 0.7011, JSD of the two dists is -0.0115
# Epoch  11 / 50, step    0 / 120; loss 0.6782
# Epoch  11 / 50, step   60 / 120; loss 0.6827
# Accuracy on training set is 0.5372916666666666
# Accuracy on test set is 0.502025
# AUC on test set is 0.5000617337500001
# BCE loss of test set is 0.7062, JSD of the two dists is -0.0189
# Epoch  12 / 50, step    0 / 120; loss 0.6847
# Epoch  12 / 50, step   60 / 120; loss 0.6881
# Accuracy on training set is 0.5395833333333333
# Accuracy on test set is 0.5013
# AUC on test set is 0.50004801875
# BCE loss of test set is 0.7063, JSD of the two dists is -0.0190
# Epoch  13 / 50, step    0 / 120; loss 0.6729
# Epoch  13 / 50, step   60 / 120; loss 0.6733
# Accuracy on training set is 0.5416083333333334
# Accuracy on test set is 0.50045
# AUC on test set is 0.500647905
# BCE loss of test set is 0.7166, JSD of the two dists is -0.0338
# Epoch  14 / 50, step    0 / 120; loss 0.6797
# Epoch  14 / 50, step   60 / 120; loss 0.6803
# Accuracy on training set is 0.5438666666666667
# Accuracy on test set is 0.5003
# AUC on test set is 0.49979037000000004
# BCE loss of test set is 0.7141, JSD of the two dists is -0.0303
# Epoch  15 / 50, step    0 / 120; loss 0.6782
# Epoch  15 / 50, step   60 / 120; loss 0.6826
# Accuracy on training set is 0.5471333333333334
# Accuracy on test set is 0.50045
# AUC on test set is 0.49873170749999995
# BCE loss of test set is 0.7067, JSD of the two dists is -0.0196
# Epoch  16 / 50, step    0 / 120; loss 0.6748
# Epoch  16 / 50, step   60 / 120; loss 0.6724
# Accuracy on training set is 0.5481583333333333
# Accuracy on test set is 0.49835
# AUC on test set is 0.49688818875000007
# BCE loss of test set is 0.7042, JSD of the two dists is -0.0160
# Epoch  17 / 50, step    0 / 120; loss 0.6778
# Epoch  17 / 50, step   60 / 120; loss 0.6711
# Accuracy on training set is 0.550675
# Accuracy on test set is 0.499275
# AUC on test set is 0.49964082750000005
# BCE loss of test set is 0.7232, JSD of the two dists is -0.0433
# Epoch  18 / 50, step    0 / 120; loss 0.6622
# Epoch  18 / 50, step   60 / 120; loss 0.6580
# Accuracy on training set is 0.5502666666666667
# Accuracy on test set is 0.498625
# AUC on test set is 0.49976131874999996
# BCE loss of test set is 0.7396, JSD of the two dists is -0.0670
# Epoch  19 / 50, step    0 / 120; loss 0.6649
# Epoch  19 / 50, step   60 / 120; loss 0.6637
# Accuracy on training set is 0.5552583333333333
# Accuracy on test set is 0.49835
# AUC on test set is 0.49934346125
# BCE loss of test set is 0.7268, JSD of the two dists is -0.0486
# Epoch  20 / 50, step    0 / 120; loss 0.6625
# Epoch  20 / 50, step   60 / 120; loss 0.6666
# Accuracy on training set is 0.55995
# Accuracy on test set is 0.49915
# AUC on test set is 0.49859455
# BCE loss of test set is 0.7361, JSD of the two dists is -0.0619
# Epoch  21 / 50, step    0 / 120; loss 0.6447
# Epoch  21 / 50, step   60 / 120; loss 0.6490
# Accuracy on training set is 0.5663166666666667
# Accuracy on test set is 0.497825
# AUC on test set is 0.49861488875000004
# BCE loss of test set is 0.7583, JSD of the two dists is -0.0940
# Epoch  22 / 50, step    0 / 120; loss 0.6241
# Epoch  22 / 50, step   60 / 120; loss 0.6495
# Accuracy on training set is 0.5725166666666667
# Accuracy on test set is 0.50165
# AUC on test set is 0.50100890125
# BCE loss of test set is 0.7740, JSD of the two dists is -0.1166
# Epoch  23 / 50, step    0 / 120; loss 0.6234
# Epoch  23 / 50, step   60 / 120; loss 0.6473
# Accuracy on training set is 0.5793166666666667
# Accuracy on test set is 0.49775
# AUC on test set is 0.4988484425
# BCE loss of test set is 0.7648, JSD of the two dists is -0.1033
# Epoch  24 / 50, step    0 / 120; loss 0.6347
# Epoch  24 / 50, step   60 / 120; loss 0.6412
# Accuracy on training set is 0.5828
# Accuracy on test set is 0.5015
# AUC on test set is 0.49925595500000003
# BCE loss of test set is 0.8050, JSD of the two dists is -0.1613
# Epoch  25 / 50, step    0 / 120; loss 0.6252
# Epoch  25 / 50, step   60 / 120; loss 0.6205
# Accuracy on training set is 0.592325
# Accuracy on test set is 0.498775
# AUC on test set is 0.500869825
# BCE loss of test set is 0.7947, JSD of the two dists is -0.1465
# Epoch  26 / 50, step    0 / 120; loss 0.6088
# Epoch  26 / 50, step   60 / 120; loss 0.6052
# Accuracy on training set is 0.5968
# Accuracy on test set is 0.502075
# AUC on test set is 0.50116601375
# BCE loss of test set is 0.8299, JSD of the two dists is -0.1973
# Epoch  27 / 50, step    0 / 120; loss 0.6269
# Epoch  27 / 50, step   60 / 120; loss 0.6138
# Accuracy on training set is 0.6060916666666667
# Accuracy on test set is 0.5019
# AUC on test set is 0.50058298375
# BCE loss of test set is 0.8267, JSD of the two dists is -0.1926
# Epoch  28 / 50, step    0 / 120; loss 0.5986
# Epoch  28 / 50, step   60 / 120; loss 0.5953
# Accuracy on training set is 0.6150166666666667
# Accuracy on test set is 0.500875
# AUC on test set is 0.5009072875
# BCE loss of test set is 0.8608, JSD of the two dists is -0.2419
# Epoch  29 / 50, step    0 / 120; loss 0.5787
# Epoch  29 / 50, step   60 / 120; loss 0.5852
# Accuracy on training set is 0.6219916666666667
# Accuracy on test set is 0.4964
# AUC on test set is 0.49811366874999996
# BCE loss of test set is 0.8950, JSD of the two dists is -0.2912
# Epoch  30 / 50, step    0 / 120; loss 0.5707
# Epoch  30 / 50, step   60 / 120; loss 0.5721
# Accuracy on training set is 0.628225
# Accuracy on test set is 0.497225
# AUC on test set is 0.49831895375
# BCE loss of test set is 0.9146, JSD of the two dists is -0.3196
# Epoch  31 / 50, step    0 / 120; loss 0.5745
# Epoch  31 / 50, step   60 / 120; loss 0.5764
# Accuracy on training set is 0.6370583333333333
# Accuracy on test set is 0.49715
# AUC on test set is 0.4974568475
# BCE loss of test set is 0.9603, JSD of the two dists is -0.3854
# Epoch  32 / 50, step    0 / 120; loss 0.5441
# Epoch  32 / 50, step   60 / 120; loss 0.5513
# Accuracy on training set is 0.641525
# Accuracy on test set is 0.4997
# AUC on test set is 0.4974606650000001
# BCE loss of test set is 1.0443, JSD of the two dists is -0.5066
# Epoch  33 / 50, step    0 / 120; loss 0.5432
# Epoch  33 / 50, step   60 / 120; loss 0.5281
# Accuracy on training set is 0.6502833333333333
# Accuracy on test set is 0.4991
# AUC on test set is 0.49564062
# BCE loss of test set is 1.0597, JSD of the two dists is -0.5289
# Epoch  34 / 50, step    0 / 120; loss 0.5480
# Epoch  34 / 50, step   60 / 120; loss 0.5098
# Accuracy on training set is 0.6594083333333334
# Accuracy on test set is 0.497475
# AUC on test set is 0.49672799
# BCE loss of test set is 1.1155, JSD of the two dists is -0.6093
# Epoch  35 / 50, step    0 / 120; loss 0.4939
# Epoch  35 / 50, step   60 / 120; loss 0.5249
# Accuracy on training set is 0.662025
# Accuracy on test set is 0.49755
# AUC on test set is 0.49674523749999994
# BCE loss of test set is 1.1816, JSD of the two dists is -0.7048
# Epoch  36 / 50, step    0 / 120; loss 0.4956
# Epoch  36 / 50, step   60 / 120; loss 0.5320
# Accuracy on training set is 0.6694583333333334
# Accuracy on test set is 0.4972
# AUC on test set is 0.49746212125
# BCE loss of test set is 1.2590, JSD of the two dists is -0.8164
# Epoch  37 / 50, step    0 / 120; loss 0.4942
# Epoch  37 / 50, step   60 / 120; loss 0.4918
# Accuracy on training set is 0.6794833333333333
# Accuracy on test set is 0.49795
# AUC on test set is 0.4963552825
# BCE loss of test set is 1.2671, JSD of the two dists is -0.8280
# Epoch  38 / 50, step    0 / 120; loss 0.4852
# Epoch  38 / 50, step   60 / 120; loss 0.4852
# Accuracy on training set is 0.682775
# Accuracy on test set is 0.498675
# AUC on test set is 0.49756595875
# BCE loss of test set is 1.3559, JSD of the two dists is -0.9561
# Epoch  39 / 50, step    0 / 120; loss 0.4776
# Epoch  39 / 50, step   60 / 120; loss 0.4857
# Accuracy on training set is 0.693675
# Accuracy on test set is 0.4964
# AUC on test set is 0.49621621000000005
# BCE loss of test set is 1.3990, JSD of the two dists is -1.0183
# Epoch  40 / 50, step    0 / 120; loss 0.4576
# Epoch  40 / 50, step   60 / 120; loss 0.4715
# Accuracy on training set is 0.701275
# Accuracy on test set is 0.498275
# AUC on test set is 0.4973218850000001
# BCE loss of test set is 1.4772, JSD of the two dists is -1.1311
# Epoch  41 / 50, step    0 / 120; loss 0.4684
# Epoch  41 / 50, step   60 / 120; loss 0.4879
# Accuracy on training set is 0.7022416666666667
# Accuracy on test set is 0.501075
# AUC on test set is 0.4997522825
# BCE loss of test set is 1.5419, JSD of the two dists is -1.2244
# Epoch  42 / 50, step    0 / 120; loss 0.4649
# Epoch  42 / 50, step   60 / 120; loss 0.4635
# Accuracy on training set is 0.7072583333333333
# Accuracy on test set is 0.4968
# AUC on test set is 0.49667363124999997
# BCE loss of test set is 1.5470, JSD of the two dists is -1.2318
# Epoch  43 / 50, step    0 / 120; loss 0.4607
# Epoch  43 / 50, step   60 / 120; loss 0.4395
# Accuracy on training set is 0.7186
# Accuracy on test set is 0.49695
# AUC on test set is 0.49690946375
# BCE loss of test set is 1.6274, JSD of the two dists is -1.3478
# Epoch  44 / 50, step    0 / 120; loss 0.4292
# Epoch  44 / 50, step   60 / 120; loss 0.4388
# Accuracy on training set is 0.7208
# Accuracy on test set is 0.498625
# AUC on test set is 0.49780660125
# BCE loss of test set is 1.7139, JSD of the two dists is -1.4727
# Epoch  45 / 50, step    0 / 120; loss 0.4367
# Epoch  45 / 50, step   60 / 120; loss 0.4018
# Accuracy on training set is 0.7273166666666666
# Accuracy on test set is 0.498825
# AUC on test set is 0.49727013750000004
# BCE loss of test set is 1.7881, JSD of the two dists is -1.5797
# Epoch  46 / 50, step    0 / 120; loss 0.4164
# Epoch  46 / 50, step   60 / 120; loss 0.4508
# Accuracy on training set is 0.73
# Accuracy on test set is 0.498875
# AUC on test set is 0.49620042249999996
# BCE loss of test set is 1.9226, JSD of the two dists is -1.7737
# Epoch  47 / 50, step    0 / 120; loss 0.4344
# Epoch  47 / 50, step   60 / 120; loss 0.4087
# Accuracy on training set is 0.7350833333333333
# Accuracy on test set is 0.495775
# AUC on test set is 0.49645144250000006
# BCE loss of test set is 1.8964, JSD of the two dists is -1.7359
# Epoch  48 / 50, step    0 / 120; loss 0.4342
# Epoch  48 / 50, step   60 / 120; loss 0.4250
# Accuracy on training set is 0.726825
# Accuracy on test set is 0.497425
# AUC on test set is 0.49809101125
# BCE loss of test set is 1.9845, JSD of the two dists is -1.8630
# Epoch  49 / 50, step    0 / 120; loss 0.3837
# Epoch  49 / 50, step   60 / 120; loss 0.3993
# Accuracy on training set is 0.741075
# Accuracy on test set is 0.4955
# AUC on test set is 0.496673385
# BCE loss of test set is 1.9650, JSD of the two dists is -1.8349
# Epoch  50 / 50, step    0 / 120; loss 0.4163
# Epoch  50 / 50, step   60 / 120; loss 0.3870
# Accuracy on training set is 0.749
# Accuracy on test set is 0.499775
# AUC on test set is 0.4984829575
# BCE loss of test set is 2.1020, JSD of the two dists is -2.0326
# classifier loaded successfully
# Now looking at independent dataset:
# Accuracy on test set is 0.50225
# AUC on test set is 0.50404002375
# BCE loss of test set is 0.6931, JSD of the two dists is 0.0001
# unrescaled calibration curve: [0.49713595 0.50185277] [0.49469796 0.50271101]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\zz-Internship\CaloChallenge\code\evaluate.py:608
#     606 with torch.no_grad():
#     607     print("Now looking at independent dataset:")
# --> 608     eval_acc, eval_auc, eval_JSD = evaluate_cls(classifier, val_dataloader, args,
#     609                                                 final_eval=True,
#     610                                                 calibration_data=test_dataloader)
#     611 print("Final result of classifier test (AUC / JSD):")
#     612 print("{:.4f} / {:.4f}".format(eval_auc, eval_JSD))
#
# File ~\zz-Internship\CaloChallenge\code\evaluate.py:315, in evaluate_cls(model, data_test, arg, final_eval, calibration_data)
#     313 prob_true, prob_pred = calibration_curve(result_true, result_pred, n_bins=10)
#     314 print("unrescaled calibration curve:", prob_true, prob_pred)
# --> 315 calibrator = calibrate_classifier(model, calibration_data, arg)
#     316 rescaled_pred = calibrator.predict(result_pred)
#     317 eval_acc = accuracy_score(result_true, np.round(rescaled_pred))
#
# File ~\zz-Internship\CaloChallenge\code\evaluate.py:341, in calibrate_classifier(model, calibration_data, arg)
#     339     data_batch = data_batch[0]
#     340 input_vector, target_vector = data_batch[:, :-1], data_batch[:, -1]
# --> 341 output_vector = model(input_vector)
#     342 pred = torch.sigmoid(output_vector).reshape(-1)
#     343 target = target_vector.to(torch.float32)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\zz-Internship\CaloChallenge\code\evaluate.py:149, in DNN.forward(self, x)
#     147 def forward(self, x):
#     148     """ Forward pass through the DNN """
# --> 149     x = self.layers(x)
#     150     return x
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 must have the same dtype, but got Double and Float

# %% [markdown]
# An AUC of as low as `0.7` is seen as good

# %% [markdown]
# # End

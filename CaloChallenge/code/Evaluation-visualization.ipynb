# %% [markdown]
# ## Evaluation of showers submitted to the Fast Calorimeter Challenge 2022

# %% [markdown]
# This is an interactive version of the file ```evaluate.py```. It can also be run directly using:
#
# ```
# python evaluate.py -i INPUT_FILE -r REFERENCE_FILE -m MODE -d DATASET --output_dir OUTPUT_DIR --source_dir SOURCE_DIR
# ```
#
# where the arguments are:
#
# - ```INPUT_FILE``` is the .hdf5 file that contains the showers to be evaluated.
#
# - ```REFERENCE_FILE``` is either the .hdf5 file that contains the showers the input is compared to, or the .pkl file that is created when the code is run for the first time. The latter contains all relevant high-level features and using it results in a faster runtime.
#
# - ```MODE``` is one of [all, avg, avg-E, hist, hist-p, hist-chi], and defaults to 'all'. 'avg' plots the average shower of all provided events; 'avg-E' plots the average shower in smaller energy ranges; 'hist' plots histograms of high-level features and saves the separation power, a measure of difference between the histogram of the provided file and the histogram of a reference in SOURCE_DIR, into a file; 'hist-p' only plots the histograms; 'hist-chi' only saves the separation power; and 'all' does all of the above.
#
# - ```DATASET``` is the name of the dataset that should be evaluated. Must be one of [1-photons, 1-pions, 2, 3].
#
# - ```OUTPUT_DIR``` is the folder in which the plots and other files will be stored. It defaults to 'evaluation_results/'.
#
# - ```SOURCE_DIR``` is the folder in which the reference .pkl will be stored. In the future, it will also be where the .hdf5 files for the classifier are saved

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/Colab Notebooks/Qibin/Internship/CaloChallenge/code'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/Qibin/Internship/CaloChallenge/code

# %%
# !pip install jetnet
# Out:
# Requirement already satisfied: jetnet in /usr/local/lib/python3.10/dist-packages (0.2.5)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from jetnet) (1.25.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from jetnet) (2.1.0+cu121)
# Requirement already satisfied: energyflow>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from jetnet) (1.3.2)
# Requirement already satisfied: scipy>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from jetnet) (1.11.4)
# Requirement already satisfied: awkward>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from jetnet) (2.6.1)
# Requirement already satisfied: coffea>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from jetnet) (2024.2.1)
# Requirement already satisfied: h5py>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from jetnet) (3.9.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from jetnet) (1.5.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.10/dist-packages (from jetnet) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from jetnet) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from jetnet) (4.66.2)
# Requirement already satisfied: awkward-cpp==29 in /usr/local/lib/python3.10/dist-packages (from awkward>=1.4.0->jetnet) (29)
# Requirement already satisfied: fsspec>=2022.11.0 in /usr/local/lib/python3.10/dist-packages (from awkward>=1.4.0->jetnet) (2023.6.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from awkward>=1.4.0->jetnet) (7.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from awkward>=1.4.0->jetnet) (23.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from awkward>=1.4.0->jetnet) (4.9.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (5.3.2)
# Requirement already satisfied: cloudpickle>=1.2.3 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (2.2.1)
# Requirement already satisfied: correctionlib>=2.3.3 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (2.5.0)
# Requirement already satisfied: dask-awkward>=2024.2.0 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (2024.2.0)
# Requirement already satisfied: dask-histogram>=2024.2.0 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (2024.2.0)
# Requirement already satisfied: dask[array]<2024.2.0,>=2023.4.0 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (2023.8.1)
# Requirement already satisfied: fsspec-xrootd>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (0.2.4)
# Requirement already satisfied: hist>=2 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (2.7.2)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (4.3.3)
# Requirement already satisfied: matplotlib>=3 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (3.7.1)
# Requirement already satisfied: mplhep>=0.1.18 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (0.3.35)
# Requirement already satisfied: numba>=0.58.1 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (0.58.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (14.0.2)
# Requirement already satisfied: toml>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (0.10.2)
# Requirement already satisfied: uproot>=5.2.2 in /usr/local/lib/python3.10/dist-packages (from coffea>=0.7.0->jetnet) (5.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from energyflow>=1.3.0->jetnet) (1.16.0)
# Requirement already satisfied: wasserstein>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from energyflow>=1.3.0->jetnet) (1.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->jetnet) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->jetnet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->jetnet) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->jetnet) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->jetnet) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jetnet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jetnet) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->jetnet) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->jetnet) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->jetnet) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->jetnet) (2024.2.2)
# Requirement already satisfied: cython>=0.29.21 in /usr/local/lib/python3.10/dist-packages (from tables->jetnet) (3.0.8)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from tables->jetnet) (2.9.0)
# Requirement already satisfied: blosc2~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from tables->jetnet) (2.0.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from tables->jetnet) (9.0.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from blosc2~=2.0.0->tables->jetnet) (1.0.7)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from correctionlib>=2.3.3->coffea>=0.7.0->jetnet) (2.6.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from correctionlib>=2.3.3->coffea>=0.7.0->jetnet) (13.7.0)
# Requirement already satisfied: boost-histogram>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from dask-histogram>=2024.2.0->coffea>=0.7.0->jetnet) (1.4.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]<2024.2.0,>=2023.4.0->coffea>=0.7.0->jetnet) (8.1.7)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]<2024.2.0,>=2023.4.0->coffea>=0.7.0->jetnet) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[array]<2024.2.0,>=2023.4.0->coffea>=0.7.0->jetnet) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]<2024.2.0,>=2023.4.0->coffea>=0.7.0->jetnet) (0.12.1)
# Requirement already satisfied: histoprint>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from hist>=2->coffea>=0.7.0->jetnet) (2.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->awkward>=1.4.0->jetnet) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->coffea>=0.7.0->jetnet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->coffea>=0.7.0->jetnet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->coffea>=0.7.0->jetnet) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->coffea>=0.7.0->jetnet) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->coffea>=0.7.0->jetnet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3->coffea>=0.7.0->jetnet) (3.1.1)
# Requirement already satisfied: mplhep-data in /usr/local/lib/python3.10/dist-packages (from mplhep>=0.1.18->coffea>=0.7.0->jetnet) (0.0.3)
# Requirement already satisfied: uhi>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from mplhep>=0.1.18->coffea>=0.7.0->jetnet) (0.4.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.58.1->coffea>=0.7.0->jetnet) (0.41.1)
# Requirement already satisfied: cramjam>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from uproot>=5.2.2->coffea>=0.7.0->jetnet) (2.8.1)
# Requirement already satisfied: wurlitzer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wasserstein>=0.3.1->energyflow>=1.3.0->jetnet) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->jetnet) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->jetnet) (1.3.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[array]<2024.2.0,>=2023.4.0->coffea>=0.7.0->jetnet) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->correctionlib>=2.3.3->coffea>=0.7.0->jetnet) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->correctionlib>=2.3.3->coffea>=0.7.0->jetnet) (2.16.2)
# ERROR: Operation cancelled by user

# %%
import os
import evaluate
import argparse
import h5py
import numpy as np


import sys
sys.path.append('/path/to/directory')

from HighLevelFeatures import HighLevelFeatures as HLF
# Out:
# /usr/local/lib/python3.10/dist-packages/jetnet/utils/utils.py:7: FutureWarning: In version 2024.7.0 (target date: 2024-06-30 11:59:59-05:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector

# %%
# specify to your needs:

INPUT_FILE = '../Datasets/dataset_2_1.hdf5' # REPLACE THIS WITH YOUR GENERATED EVENTS
REFERENCE_FILE = '../Datasets/dataset_2_2.hdf5' # These are the GEANT evaluation events that are provided on zenodo
#REFERENCE_FILE = 'source/dataset_2_2.pkl' # This is computed in the first run of the notebook. It can be used instead of the .hdf5 to save time in subsequent runs.




MODE = 'all' # not really needed here because the nb is interactive


DATASET = '2'
OUTPUT_DIR = 'evaluation_results/'
SOURCE_DIR = '../Datasets/'

# %%
# emulating the argument parser of evaluate.py
parser_replacement = {
    'input_file': INPUT_FILE, 'reference_file': REFERENCE_FILE, 'mode': MODE, 'dataset': DATASET,
    'output_dir': OUTPUT_DIR, 'source_dir': SOURCE_DIR, }
args = argparse.Namespace(**parser_replacement)

# %%
# reading in source file
source_file = h5py.File(args.input_file, 'r')

# checking if it has correct shape
evaluate.check_file(source_file, args)

# preparing output directory
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# preparing source directory
if not os.path.isdir(args.source_dir):
    os.makedirs(args.source_dir)

# extracting showers and energies from source file
shower, energy = evaluate.extract_shower_and_energy(source_file, which= "input")



# with h5py.File(INPUT_FILE, 'r') as input_file:
#     # Create a new HDF5 file in write mode
#     energy = input_file['incident_energies']
#     shower = input_file['showers']



# creating helper class for high-level features
particle = {'1-photons': 'photon', '1-pions': 'pion',
            '2': 'electron', '3': 'electron'}[args.dataset]
hlf = HLF(particle, filename='binning_dataset_{}.xml'.format(args.dataset.replace('-', '_')))

del source_file
# Out:
# Checking if provided file has the correct form ...
# Found 100000 events in the file.
# Checking if provided file has the correct form: DONE
#
# Extracting showers from input file ...
# Extracting energy from input file: DONE.

# %%
# Out:
# (100000, 6480)

# %%
_ = hlf.DrawAverageShower(shower, filename=os.path.join(args.output_dir,
                                                        'average_shower_dataset_{}.png'.format(args.dataset)),
                                  title="Shower average")

# %%
# reading in reference

if os.path.splitext(args.reference_file)[1] == '.hdf5':
    print("using .hdf5 reference")
    reference_file = h5py.File(args.reference_file, 'r')
    evaluate.check_file(reference_file, args, which='reference')
    reference_hlf = HLF(particle, filename='binning_dataset_{}.xml'.format(
        args.dataset.replace('-', '_')))
    reference_shower, reference_energy = evaluate.extract_shower_and_energy(reference_file, which='reference')
    reference_hlf.Einc = reference_energy
    evaluate.save_reference(reference_hlf, args.reference_file)

elif os.path.splitext(args.reference_file)[1] == '.pkl':
    print("using .pkl file for reference")
    reference_hlf = evaluate.load_reference(args.reference_file)
else:
    raise ValueError("reference_file must be .hdf5 or .pkl!")
# Out:
# using .hdf5 reference
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-52efbe2f6034> in <cell line: 3>()
#       3 if os.path.splitext(args.reference_file)[1] == '.hdf5':
#       4     print("using .hdf5 reference")
# ----> 5     reference_file = h5py.File(args.reference_file, 'r')
#       6     evaluate.check_file(reference_file, args, which='reference')
#       7     reference_hlf = HLF(particle, filename='binning_dataset_{}.xml'.format(
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     565                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                                  fs_page_size=fs_page_size)
# --> 567                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     568
#     569             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.10/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229         if swmr and swmr_support:
#     230             flags |= h5f.ACC_SWMR_READ
# --> 231         fid = h5f.open(name, flags, fapl=fapl)
#     232     elif mode == 'r+':
#     233         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)

# %% [markdown]
# ### The cells below correspond to different evaluation MODEs and can be run independent of each other.

# %%
# evaluation mode 'avg': average of given showers
print("Plotting average shower...")
_ = hlf.DrawAverageShower(shower, filename=os.path.join(args.output_dir,
                                                        'average_shower_dataset_{}.png'.format(args.dataset)),
                                  title="Shower average")
if hasattr(reference_hlf, 'avg_shower'):
    pass
else:
    reference_hlf.avg_shower = reference_shower.mean(axis=0, keepdims=True)
    evaluate.save_reference(reference_hlf, args.reference_file)
_ = hlf.DrawAverageShower(reference_hlf.avg_shower,
                          filename=os.path.join(args.output_dir, 'reference_average_shower_dataset_{}.png'.format(
                                          args.dataset)),
                          title="Shower average reference dataset")
print("Plotting average shower: DONE.\n")
# Out:
# Plotting average shower...
# Plotting average shower: DONE.

# %%
# evaluation mode 'avg-E': average showers at different energy ranges
print("Plotting average showers for different energies ...")
if '1' in args.dataset:
    target_energies = 2**np.linspace(8, 23, 16)
    plot_title = ['shower average at E = {} MeV'.format(int(en)) for en in target_energies]
else:
    target_energies = 10**np.linspace(3, 6, 4)
    plot_title = []
    for i in range(3, 7):
        plot_title.append('shower average for E in [{}, {}] MeV'.format(10**i, 10**(i+1)))
for i in range(len(target_energies)-1):
    filename = 'average_shower_dataset_{}_E_{}.png'.format(args.dataset,
                                                                   target_energies[i])
    which_showers = ((energy >= target_energies[i]) & (energy < target_energies[i+1])).squeeze()
    _ = hlf.DrawAverageShower(shower[which_showers],
                              filename=os.path.join(args.output_dir, filename),
                              title=plot_title[i])
    if hasattr(reference_hlf, 'avg_shower_E'):
        pass
    else:
        reference_hlf.avg_shower_E = {}
    if target_energies[i] in reference_hlf.avg_shower_E:
        pass
    else:
        which_showers = ((reference_hlf.Einc >= target_energies[i]) & (reference_hlf.Einc < target_energies[i+1])).squeeze()
        reference_hlf.avg_shower_E[target_energies[i]] = reference_shower[which_showers].mean(axis=0, keepdims=True)
        evaluate.save_reference(reference_hlf, args.reference_file, args)

        _ = hlf.DrawAverageShower(reference_hlf.avg_shower_E[target_energies[i]],
                                  filename=os.path.join(args.output_dir, 'reference_'+filename),
                                  title='reference '+plot_title[i])

print("Plotting average shower for different energies: DONE.\n")
# Out:
# Plotting average showers for different energies ...

# %%
# evaluation mode 'hist': plotting histograms of high-level features and printing/saving the sepration power
# (equivalent to running hist-p for plotting and hist-chi for the separation power)
print("Calculating high-level features for histograms ...")
hlf.CalculateFeatures(shower)
hlf.Einc = energy

print("Calculating high-level features for histograms: DONE.\n")
if reference_hlf.E_tot is None:
    reference_hlf.CalculateFeatures(reference_shower)
    evaluate.save_reference(reference_hlf, args.reference_file, args)
print("Calculating high-level features for histograms: DONE.\n")

with open(os.path.join(args.output_dir, 'histogram_chi2_{}.txt'.format(args.dataset)), 'w') as f:
    f.write('List of chi2 of the plotted histograms, see eq. 15 of 2009.03796 for its definition.\n')
print("Plotting histograms ...")
evaluate.plot_histograms(hlf, reference_hlf, args)
print("Plotting histograms: DONE. \n")
# Out:
# Calculating high-level features for histograms ...
# Calculating high-level features for histograms: DONE.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-62886b41ca5d> in <cell line: 8>()
#       6
#       7 print("Calculating high-level features for histograms: DONE.\n")
# ----> 8 if reference_hlf.E_tot is None:
#       9     reference_hlf.CalculateFeatures(reference_shower)
#      10     evaluate.save_reference(reference_hlf, args.reference_file, args)
#
# NameError: name 'reference_hlf' is not defined
